# %% [markdown]
# # Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# ## Importing Data from JSON files

# %%
import pandas as pd
import json

# %%
with open("blockbusters.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'title': 'Avengers: Endgame',
#   'id': 299534,
#   'revenue': 2797800564,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 181},
#  {'title': 'Avatar',
#   'id': 19995,
#   'revenue': 2787965087,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   'runtime': 162},
#  {'title': 'Star Wars: The Force Awakens',
#   'id': 140607,
#   'revenue': 2068223624,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 136},
#  {'title': 'Avengers: Infinity War',
#   'id': 299536,
#   'revenue': 2046239637,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 149},
#  {'title': 'Titanic',
#   'id': 597,
#   'revenue': 1845034188,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': None,
#   'runtime': 194},
#  {'title': 'Jurassic World',
#   'id': 135397,
#   'revenue': 1671713208,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 124},
#  {'title': 'The Lion King',
#   'id': 420818,
#   'revenue': 1656943394,
#   'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': None,
#   'runtime': 118},
#  {'title': 'The Avengers',
#   'id': 24428,
#   'revenue': 1519557910,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 143},
#  {'title': 'Furious 7',
#   'id': 168259,
#   'revenue': 1506249360,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/uv63yAGg1zETAs1XQsOQpava87l.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'runtime': 137},
#  {'title': 'Avengers: Age of Ultron',
#   'id': 99861,
#   'revenue': 1405403694,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 141},
#  {'title': 'Black Panther',
#   'id': 284054,
#   'revenue': 1346739107,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg',
#    'backdrop_path': '/1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg'},
#   'runtime': 134},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'id': 12445,
#   'revenue': 1341511219,
#   'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg'},
#   'runtime': 130},
#  {'title': 'Star Wars: The Last Jedi',
#   'id': 181808,
#   'revenue': 1332539889,
#   'genres': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 152},
#  {'title': 'Frozen II',
#   'id': 330457,
#   'revenue': 1330764959,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 104},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'id': 351286,
#   'revenue': 1303459585,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 129},
#  {'title': 'Frozen',
#   'id': 109445,
#   'revenue': 1274219009,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 102},
#  {'title': 'Beauty and the Beast',
#   'id': 321612,
#   'revenue': 1263521126,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'belongs_to_collection': None,
#   'runtime': 129},
#  {'title': 'Incredibles 2',
#   'id': 260513,
#   'revenue': 1241891456,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/l7GqbzkJwowYRIXAtUz2iCPi64a.jpg',
#    'backdrop_path': '/9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg'},
#   'runtime': 118}]

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 18

# %%
data[0]
# Out:
# {'title': 'Avengers: Endgame',
#  'id': 299534,
#  'revenue': 2797800564,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'}],
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'runtime': 181}

# %%
df = pd.DataFrame(data)
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df = pd.read_json("blockbusters.json", orient = "record")
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18 non-null     object
#  1   id                     18 non-null     int64
#  2   revenue                18 non-null     int64
#  3   genres                 18 non-null     object
#  4   belongs_to_collection  15 non-null     object
#  5   runtime                18 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 996.0+ bytes

# %%
df.genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 86311,
#  'name': 'The Avengers Collection',
#  'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#  'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}

# %%
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  runtime  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      181
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      162
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      136
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      149
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      194
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      124
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...      118
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...      143
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      137
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      141
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      134
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      130
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      152
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...      104
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      129
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...      102
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...      129
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      118
#
#     belongs_to_collection_id           belongs_to_collection_name  \
# 0                    86311.0              The Avengers Collection
# 1                    87096.0                    Avatar Collection
# 2                       10.0                 Star Wars Collection
# 3                    86311.0              The Avengers Collection
# 4                        NaN                                  NaN
# 5                      328.0             Jurassic Park Collection
# 6                        NaN                                  NaN
# 7                    86311.0              The Avengers Collection
# 8                     9485.0  The Fast and the Furious Collection
# 9                    86311.0              The Avengers Collection
# 10                  529892.0             Black Panther Collection
# 11                    1241.0              Harry Potter Collection
# 12                      10.0                 Star Wars Collection
# 13                  386382.0                    Frozen Collection
# 14                     328.0             Jurassic Park Collection
# 15                  386382.0                    Frozen Collection
# 16                       NaN                                  NaN
# 17                  468222.0           The Incredibles Collection
#
#    belongs_to_collection_poster_path belongs_to_collection_backdrop_path  \
# 0   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 1   /nslJVsO58Etqkk17oXMuVK4gNOF.jpg    /8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg
# 2   /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 3   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 4                                NaN                                 NaN
# 5   /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 6                                NaN                                 NaN
# 7   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 8   /uv63yAGg1zETAs1XQsOQpava87l.jpg    /z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg
# 9   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 10  /9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 11  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg
# 12  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 13  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 14  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 15  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 16                               NaN                                 NaN
# 17  /l7GqbzkJwowYRIXAtUz2iCPi64a.jpg    /9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg
#
#     belongs_to_collection
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN

# %%
pd.json_normalize(data = data, sep = "_").genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
pd.json_normalize(data = data, record_path = "genres", meta = ["title", "id"],
                  record_prefix = "genre_")
# Out:
#     genre_id       genre_name                                         title  \
# 0         12        Adventure                             Avengers: Endgame
# 1        878  Science Fiction                             Avengers: Endgame
# 2         28           Action                             Avengers: Endgame
# 3         28           Action                                        Avatar
# 4         12        Adventure                                        Avatar
# 5         14          Fantasy                                        Avatar
# 6        878  Science Fiction                                        Avatar
# 7         28           Action                  Star Wars: The Force Awakens
# 8         12        Adventure                  Star Wars: The Force Awakens
# 9        878  Science Fiction                  Star Wars: The Force Awakens
# 10        14          Fantasy                  Star Wars: The Force Awakens
# 11        12        Adventure                        Avengers: Infinity War
# 12        28           Action                        Avengers: Infinity War
# 13       878  Science Fiction                        Avengers: Infinity War
# 14        18            Drama                                       Titanic
# 15     10749          Romance                                       Titanic
# 16        53         Thriller                                       Titanic
# 17        28           Action                                Jurassic World
# 18        12        Adventure                                Jurassic World
# 19       878  Science Fiction                                Jurassic World
# 20        53         Thriller                                Jurassic World
# 21        12        Adventure                                 The Lion King
# 22     10751           Family                                 The Lion King
# 23       878  Science Fiction                                  The Avengers
# 24        28           Action                                  The Avengers
# 25        12        Adventure                                  The Avengers
# 26        28           Action                                     Furious 7
# 27        53         Thriller                                     Furious 7
# 28        28           Action                       Avengers: Age of Ultron
# 29        12        Adventure                       Avengers: Age of Ultron
# 30       878  Science Fiction                       Avengers: Age of Ultron
# 31        28           Action                                 Black Panther
# 32        12        Adventure                                 Black Panther
# 33        14          Fantasy                                 Black Panther
# 34       878  Science Fiction                                 Black Panther
# 35        14          Fantasy  Harry Potter and the Deathly Hallows: Part 2
# 36        12        Adventure  Harry Potter and the Deathly Hallows: Part 2
# 37        14          Fantasy                      Star Wars: The Last Jedi
# 38        12        Adventure                      Star Wars: The Last Jedi
# 39       878  Science Fiction                      Star Wars: The Last Jedi
# 40        28           Action                      Star Wars: The Last Jedi
# 41        16        Animation                                     Frozen II
# 42     10751           Family                                     Frozen II
# 43        12        Adventure                                     Frozen II
# 44        28           Action                Jurassic World: Fallen Kingdom
# 45        12        Adventure                Jurassic World: Fallen Kingdom
# 46       878  Science Fiction                Jurassic World: Fallen Kingdom
# 47        16        Animation                                        Frozen
# 48        12        Adventure                                        Frozen
# 49     10751           Family                                        Frozen
# 50     10751           Family                          Beauty and the Beast
# 51        14          Fantasy                          Beauty and the Beast
# 52     10749          Romance                          Beauty and the Beast
# 53        28           Action                                 Incredibles 2
# 54        12        Adventure                                 Incredibles 2
# 55        16        Animation                                 Incredibles 2
# 56     10751           Family                                 Incredibles 2
#
#         id
# 0   299534
# 1   299534
# 2   299534
# 3    19995
# 4    19995
# 5    19995
# 6    19995
# 7   140607
# 8   140607
# 9   140607
# 10  140607
# 11  299536
# 12  299536
# 13  299536
# 14     597
# 15     597
# 16     597
# 17  135397
# 18  135397
# 19  135397
# 20  135397
# 21  420818
# 22  420818
# 23   24428
# 24   24428
# 25   24428
# 26  168259
# 27  168259
# 28   99861
# 29   99861
# 30   99861
# 31  284054
# 32  284054
# 33  284054
# 34  284054
# 35   12445
# 36   12445
# 37  181808
# 38  181808
# 39  181808
# 40  181808
# 41  330457
# 42  330457
# 43  330457
# 44  351286
# 45  351286
# 46  351286
# 47  109445
# 48  109445
# 49  109445
# 50  321612
# 51  321612
# 52  321612
# 53  260513
# 54  260513
# 55  260513
# 56  260513

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %%
api_key  = "api_key=64e6e82b9e2df65036fbdf3b1b4d283f"

# %%
#example: assume your personal api-key is "123abc"
api_key  = "api_key=64e6e82b9e2df65036fbdf3b1b4d283f"

# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
movie_id = 140607

# %%
movie_api = "https://api.themoviedb.org/3/movie/{}?"
movie_api
# Out:
# 'https://api.themoviedb.org/3/movie/{}?'

# %%
url = movie_api.format(movie_id) + api_key
url
# Out:
# 'https://api.themoviedb.org/3/movie/140607?api_key=64e6e82b9e2df65036fbdf3b1b4d283f'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
data
# Out:
# {'adult': False,
#  'backdrop_path': '/k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg',
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#  'budget': 245000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#  'id': 140607,
#  'imdb_id': 'tt2488496',
#  'original_language': 'en',
#  'original_title': 'Star Wars: The Force Awakens',
#  'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#  'popularity': 57.727,
#  'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#  'production_companies': [{'id': 1,
#    'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#    'name': 'Lucasfilm Ltd.',
#    'origin_country': 'US'},
#   {'id': 11461,
#    'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#    'name': 'Bad Robot',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2015-12-15',
#  'revenue': 2068223624,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Every generation has a story.',
#  'title': 'Star Wars: The Force Awakens',
#  'video': False,
#  'vote_average': 7.285,
#  'vote_count': 18782}

# %%
type(data)
# Out:
# dict

# %%
# pd.DataFrame(data)

# %%
pd.Series(data)
# Out:
# adult                                                                False
# backdrop_path                             /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# belongs_to_collection    {'id': 10, 'name': 'Star Wars Collection', 'po...
# budget                                                           245000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# homepage                 http://www.starwars.com/films/star-wars-episod...
# id                                                                  140607
# imdb_id                                                          tt2488496
# original_language                                                       en
# original_title                                Star Wars: The Force Awakens
# overview                 Thirty years after defeating the Galactic Empi...
# popularity                                                          57.727
# poster_path                               /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# production_companies     [{'id': 1, 'logo_path': '/tlVSws0RvvtPBwViUyOF...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    2015-12-15
# revenue                                                         2068223624
# runtime                                                                136
# spoken_languages         [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                            Released
# tagline                                      Every generation has a story.
# title                                         Star Wars: The Force Awakens
# video                                                                False
# vote_average                                                         7.285
# vote_count                                                           18782
# dtype: object

# %%
df = pd.Series(data).to_frame().T
df
# Out:
#    adult                     backdrop_path  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview popularity  \
# 0  Thirty years after defeating the Galactic Empi...     57.727
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/tlVSws0RvvtPBwViUyOF...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#   runtime                                   spoken_languages    status  \
# 0     136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#   vote_average vote_count
# 0        7.285      18782

# %%
pd.json_normalize(data, sep = "_")
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg  245000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview  popularity  \
# 0  Thirty years after defeating the Galactic Empi...      57.727
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/tlVSws0RvvtPBwViUyOF...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#    runtime                                   spoken_languages    status  \
# 0      136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#    vote_average  vote_count  belongs_to_collection_id  \
# 0         7.285       18782                        10
#
#   belongs_to_collection_name belongs_to_collection_poster_path  \
# 0       Star Wars Collection  /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg
#
#   belongs_to_collection_backdrop_path
# 0    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg

# %%
pd.json_normalize(data = data, record_path = "genres", meta = "title", record_prefix = "genre_")
# Out:
#    genre_id       genre_name                         title
# 0        12        Adventure  Star Wars: The Force Awakens
# 1        28           Action  Star Wars: The Force Awakens
# 2       878  Science Fiction  Star Wars: The Force Awakens

# %%
pd.json_normalize(data = data, record_path = "production_companies", meta = "title",record_prefix = "prod_comp_")
# Out:
#    prod_comp_id               prod_comp_logo_path  prod_comp_name  \
# 0             1  /tlVSws0RvvtPBwViUyOFAO0vcQS.png  Lucasfilm Ltd.
# 1         11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png       Bad Robot
#
#   prod_comp_origin_country                         title
# 0                       US  Star Wars: The Force Awakens
# 1                       US  Star Wars: The Force Awakens

# %% [markdown]
# ## Working with APIs and JSON (Part 2)

# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
discover_api = "https://api.themoviedb.org/3/discover/movie?"

# %%
query = "&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29"

# %%
url = discover_api+api_key+query

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tintsaQ0WLzZsTMkTiqtMB3rfc8.jpg',
#    'genre_ids': [28, 80, 35],
#    'id': 522627,
#    'original_language': 'en',
#    'original_title': 'The Gentlemen',
#    'overview': 'American expat Mickey Pearson has built a highly profitable marijuana empire in London. When word gets out that he’s looking to cash out of the business forever it triggers plots, schemes, bribery and blackmail in an attempt to steal his domain out from under him.',
#    'popularity': 97.875,
#    'poster_path': '/jtrhTYB7xSrJxR1vusu99nvnZ1g.jpg',
#    'release_date': '2020-01-01',
#    'title': 'The Gentlemen',
#    'video': False,
#    'vote_average': 7.681,
#    'vote_count': 5392},
#   {'adult': False,
#    'backdrop_path': '/stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg',
#    'genre_ids': [28, 878, 35, 10751],
#    'id': 454626,
#    'original_language': 'en',
#    'original_title': 'Sonic the Hedgehog',
#    'overview': 'Powered with incredible speed, Sonic The Hedgehog embraces his new home on Earth. That is, until Sonic sparks the attention of super-uncool evil genius Dr. Robotnik. Now it’s super-villain vs. super-sonic in an all-out race across the globe to stop Robotnik from using Sonic’s unique power for world domination.',
#    'popularity': 67.362,
#    'poster_path': '/aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg',
#    'release_date': '2020-02-12',
#    'title': 'Sonic the Hedgehog',
#    'video': False,
#    'vote_average': 7.333,
#    'vote_count': 9175},
#   {'adult': False,
#    'backdrop_path': '/eAIHqfS3kXm7kZl4j7ZBfdegyEz.jpg',
#    'genre_ids': [53, 28, 80],
#    'id': 38700,
#    'original_language': 'en',
#    'original_title': 'Bad Boys for Life',
#    'overview': 'Marcus and Mike are forced to confront new threats, career changes, and midlife crises as they join the newly created elite team AMMO of the Miami police department to take down the ruthless Armando Armas, the vicious leader of a Miami drug cartel.',
#    'popularity': 54.064,
#    'poster_path': '/y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg',
#    'release_date': '2020-01-15',
#    'title': 'Bad Boys for Life',
#    'video': False,
#    'vote_average': 7.13,
#    'vote_count': 7720},
#   {'adult': False,
#    'backdrop_path': '/7dCzb1oa7ACYi66VIrE1wqmftAa.jpg',
#    'genre_ids': [28],
#    'id': 660521,
#    'original_language': 'en',
#    'original_title': 'The Mercenary',
#    'overview': 'When a mission in South America goes wrong a mercenary is left for dead, but he is nursed back to health and reborn with a new outlook on life. But his peaceful days are short-lived when mercenaries he used to work with cross his path again and he is forced to revisit and face his own demons.',
#    'popularity': 47.497,
#    'poster_path': '/p3wgefagejlefFEDsLRHiXU7NGu.jpg',
#    'release_date': '2020-01-07',
#    'title': 'The Mercenary',
#    'video': False,
#    'vote_average': 6.104,
#    'vote_count': 24},
#   {'adult': False,
#    'backdrop_path': '/xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg',
#    'genre_ids': [10751, 16, 12, 35, 14],
#    'id': 508439,
#    'original_language': 'en',
#    'original_title': 'Onward',
#    'overview': 'In a suburban fantasy world, two teenage elf brothers embark on an extraordinary quest to discover if there is still a little magic left out there.',
#    'popularity': 43.404,
#    'poster_path': '/f4aul3FyD3jv3v4bul1IrkWZvzq.jpg',
#    'release_date': '2020-02-29',
#    'title': 'Onward',
#    'video': False,
#    'vote_average': 7.703,
#    'vote_count': 5893},
#   {'adult': False,
#    'backdrop_path': '/uozb2VeD87YmhoUP1RrGWfzuCrr.jpg',
#    'genre_ids': [28, 80],
#    'id': 495764,
#    'original_language': 'en',
#    'original_title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'overview': 'Harley Quinn joins forces with a singer, an assassin and a police detective to help a young girl who had a hit placed on her after she stole a rare diamond from a crime lord.',
#    'popularity': 40.33,
#    'poster_path': '/h4VB6m0RwcicVEZvzftYZyKXs6K.jpg',
#    'release_date': '2020-02-05',
#    'title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 9903},
#   {'adult': False,
#    'backdrop_path': '/ww7eC3BqSbFsyE5H5qMde8WkxJ2.jpg',
#    'genre_ids': [27, 878, 28, 12],
#    'id': 443791,
#    'original_language': 'en',
#    'original_title': 'Underwater',
#    'overview': 'After an earthquake destroys their underwater station, six researchers must navigate two miles along the dangerous, unknown depths of the ocean floor to make it to safety in a race against time.',
#    'popularity': 37.901,
#    'poster_path': '/gzlbb3yeVISpQ3REd3Ga1scWGTU.jpg',
#    'release_date': '2020-01-08',
#    'title': 'Underwater',
#    'video': False,
#    'vote_average': 6.287,
#    'vote_count': 2943},
#   {'adult': False,
#    'backdrop_path': '/2cbUXan4QUY1QoVnhhunJqpKR8y.jpg',
#    'genre_ids': [10751, 35, 14, 12],
#    'id': 448119,
#    'original_language': 'en',
#    'original_title': 'Dolittle',
#    'overview': 'After losing his wife seven years earlier, the eccentric Dr. John Dolittle, famed doctor and veterinarian of Queen Victoria’s England, hermits himself away behind the high walls of Dolittle Manor with only his menagerie of exotic animals for company. But when the young queen falls gravely ill, a reluctant Dolittle is forced to set sail on an epic adventure to a mythical island in search of a cure, regaining his wit and courage as he crosses old adversaries and discovers wondrous creatures.',
#    'popularity': 36.406,
#    'poster_path': '/uoplwswBDy7gsOyrbGuKyPFoPCs.jpg',
#    'release_date': '2020-01-02',
#    'title': 'Dolittle',
#    'video': False,
#    'vote_average': 6.623,
#    'vote_count': 3497},
#   {'adult': False,
#    'backdrop_path': '/sizHX5VbwlBihaathTQHVGk1jdi.jpg',
#    'genre_ids': [878, 18, 28],
#    'id': 514207,
#    'original_language': 'ru',
#    'original_title': 'Вторжение',
#    'overview': 'Two years after the fall of the alien ship, the life of a young woman from Moscow has been changed forever. Her growing powers are now at the focus of both human and celestial investigation: an alien force takes an interest in her, and will stop short of nothing, including an invasion. Can love and compassion save humanity, when faced with a much greater and more demanding test this time?',
#    'popularity': 35.654,
#    'poster_path': '/dqKqzcdhtJwOhjqe89RTURqILtl.jpg',
#    'release_date': '2020-01-01',
#    'title': 'Invasion',
#    'video': False,
#    'vote_average': 6.929,
#    'vote_count': 760},
#   {'adult': False,
#    'backdrop_path': '/8HbqSozBJxv6UldR9lMUECUlbLI.jpg',
#    'genre_ids': [878, 12, 28],
#    'id': 430155,
#    'original_language': 'ru',
#    'original_title': 'Кома',
#    'overview': 'A young and talented architect comes to his senses after a horrific accident only to find himself in the odd dystopian world. A world that is filled with the memories of all current coma patients. Just like a human memory this world is fragmental, chaotic and unstable. This is COMA: icecaps, rivers and cities can all exist in a space of a single room and laws of physics are no longer laws as they can be bent.',
#    'popularity': 33.987,
#    'poster_path': '/ijJm0RSeKIr67qkHLtSmtigS6ra.jpg',
#    'release_date': '2020-01-01',
#    'title': 'Coma',
#    'video': False,
#    'vote_average': 6.392,
#    'vote_count': 499},
#   {'adult': False,
#    'backdrop_path': '/tQprwIKzFx83JpM5dVrGRC4UpF.jpg',
#    'genre_ids': [16, 12, 14, 9648],
#    'id': 573730,
#    'original_language': 'ja',
#    'original_title': '劇場版メイドインアビス 深き魂の黎明',
#    'overview': "A continuation of the epic adventure of plucky Riko and Reg who are joined by their new friend Nanachi. Together they descend into the Abyss' treacherous fifth layer, the Sea of Corpses, and encounter the mysterious Bondrewd, a legendary White Whistle whose shadow looms over Nanachi's troubled past. Bondrewd is ingratiatingly hospitable, but the brave adventurers know things are not always as they seem in the enigmatic Abyss.",
#    'popularity': 29.612,
#    'poster_path': '/fsPZdpocYYbvDS2YEE1Xohqo1ni.jpg',
#    'release_date': '2020-01-17',
#    'title': 'Made in Abyss: Dawn of the Deep Soul',
#    'video': False,
#    'vote_average': 7.899,
#    'vote_count': 203},
#   {'adult': False,
#    'backdrop_path': '/dzfiE2VHY362dGI62XfZ2iI87CT.jpg',
#    'genre_ids': [27, 14, 12, 9648],
#    'id': 539537,
#    'original_language': 'en',
#    'original_title': 'Fantasy Island',
#    'overview': 'A group of contest winners arrive at an island hotel to live out their dreams, only to find themselves trapped in nightmare scenarios.',
#    'popularity': 29.065,
#    'poster_path': '/8ZMrZGGW65ePWIgRn1260nA1uUm.jpg',
#    'release_date': '2020-02-12',
#    'title': 'Fantasy Island',
#    'video': False,
#    'vote_average': 5.815,
#    'vote_count': 2331},
#   {'adult': False,
#    'backdrop_path': '/3pIqd1hgZ2xqzWEyiYp4blqE9Fi.jpg',
#    'genre_ids': [53, 36, 18],
#    'id': 522241,
#    'original_language': 'en',
#    'original_title': 'The Courier',
#    'overview': 'Cold War spy Greville Wynne and his Russian source try to put an end to the Cuban Missile Crisis.',
#    'popularity': 28.853,
#    'poster_path': '/zFIjKtZrzhmc7HecdFXXjsLR2Ig.jpg',
#    'release_date': '2020-01-24',
#    'title': 'The Courier',
#    'video': False,
#    'vote_average': 7.039,
#    'vote_count': 1036},
#   {'adult': False,
#    'backdrop_path': '/23IeumCWwWE7u2d2FDNSGPsNRbl.jpg',
#    'genre_ids': [18, 27, 53],
#    'id': 474764,
#    'original_language': 'en',
#    'original_title': 'The Lodge',
#    'overview': "When a father is forced to abruptly depart for work, he leaves his children, Aidan and Mia, at their holiday home in the care of his new girlfriend, Grace. Isolated and alone, a blizzard traps them inside the lodge as terrifying events summon specters from Grace's dark past.",
#    'popularity': 27.495,
#    'poster_path': '/yake2myhbW7c6dKbmwYDy1i40bm.jpg',
#    'release_date': '2020-01-16',
#    'title': 'The Lodge',
#    'video': False,
#    'vote_average': 6.121,
#    'vote_count': 1170},
#   {'adult': False,
#    'backdrop_path': '/42gqGeyXh4caHP19Tqf8DMRgc7r.jpg',
#    'genre_ids': [35, 10749],
#    'id': 556678,
#    'original_language': 'en',
#    'original_title': 'Emma.',
#    'overview': 'In 1800s England, a well-meaning but selfish young woman meddles in the love lives of her friends.',
#    'popularity': 26.989,
#    'poster_path': '/uHpHzbHLSsVmAuuGuQSpyVDZmDc.jpg',
#    'release_date': '2020-02-13',
#    'title': 'Emma.',
#    'video': False,
#    'vote_average': 7.041,
#    'vote_count': 1628},
#   {'adult': False,
#    'backdrop_path': '/6mKAKhj8POVGqV1GsroS5mGIUe9.jpg',
#    'genre_ids': [14, 28, 12],
#    'id': 666750,
#    'original_language': 'en',
#    'original_title': 'Dragonheart: Vengeance',
#    'overview': 'Lukas, a young farmer whose family is killed by savage raiders in the countryside, sets out on an epic quest for revenge, forming an unlikely trio with a majestic dragon and a swashbuckling, sword-fighting mercenary, Darius.',
#    'popularity': 26.776,
#    'poster_path': '/qs6gz6atyQcAvqC6qZaslOjliUG.jpg',
#    'release_date': '2020-02-04',
#    'title': 'Dragonheart: Vengeance',
#    'video': False,
#    'vote_average': 6.877,
#    'vote_count': 300},
#   {'adult': False,
#    'backdrop_path': '/pQdZmXq0vvKP1RYUrDHQkzMlS4x.jpg',
#    'genre_ids': [16, 28, 12, 14],
#    'id': 571265,
#    'original_language': 'ja',
#    'original_title': 'デジモンアドベンチャー LAST EVOLUTION 絆',
#    'overview': 'Tai is now a university student, living alone, working hard at school, and working every day, but with his future still undecided. Meanwhile, Matt and others continue to work on Digimon incidents and activities that help people with their partner Digimon. When an unprecedented phenomenon occurs, the DigiDestined discover that when they grow up, their relationship with their partner Digimon will come closer to an end.  As a countdown timer activates on the Digivice, they realize that the more they fight with their partner Digimon, the faster their bond breaks. Will they fight for others and lose their partner? The time to choose and decide is approaching fast. There is a short time before “chosen children” will become adults. This is the last adventure of Tai and Agumon.',
#    'popularity': 26.753,
#    'poster_path': '/z3l5iwWQLxcInVnNkC8k8hxqZ60.jpg',
#    'release_date': '2020-02-21',
#    'title': 'Digimon Adventure: Last Evolution Kizuna',
#    'video': False,
#    'vote_average': 8.1,
#    'vote_count': 231},
#   {'adult': False,
#    'backdrop_path': '/yFRpUmsreYO5Bc0HVBTsJsHIIox.jpg',
#    'genre_ids': [12, 10751, 18],
#    'id': 481848,
#    'original_language': 'en',
#    'original_title': 'The Call of the Wild',
#    'overview': 'Buck is a big-hearted dog whose blissful domestic life is turned upside down when he is suddenly uprooted from his California home and transplanted to the exotic wilds of the Yukon during the Gold Rush of the 1890s. As the newest rookie on a mail delivery dog sled team—and later its leader—Buck experiences the adventure of a lifetime, ultimately finding his true place in the world and becoming his own master.',
#    'popularity': 26.029,
#    'poster_path': '/33VdppGbeNxICrFUtW2WpGHvfYc.jpg',
#    'release_date': '2020-02-19',
#    'title': 'The Call of the Wild',
#    'video': False,
#    'vote_average': 7.567,
#    'vote_count': 3543},
#   {'adult': False,
#    'backdrop_path': '/tcrNJfyNEIqaBR8Ogkgnq5xQJnf.jpg',
#    'genre_ids': [10749, 18],
#    'id': 342470,
#    'original_language': 'en',
#    'original_title': 'All the Bright Places',
#    'overview': 'Two teens facing personal struggles form a powerful bond as they embark on a cathartic journey chronicling the wonders of Indiana.',
#    'popularity': 25.525,
#    'poster_path': '/4SafxuMKQiw4reBiWKVZJpJn80I.jpg',
#    'release_date': '2020-02-28',
#    'title': 'All the Bright Places',
#    'video': False,
#    'vote_average': 7.655,
#    'vote_count': 2767},
#   {'adult': False,
#    'backdrop_path': '/tweDJNQzBGgsWVF5MC8JhSAk07p.jpg',
#    'genre_ids': [53, 878, 27],
#    'id': 570670,
#    'original_language': 'en',
#    'original_title': 'The Invisible Man',
#    'overview': "When Cecilia's abusive ex takes his own life and leaves her his fortune, she suspects his death was a hoax. As a series of coincidences turn lethal, Cecilia works to prove that she is being hunted by someone nobody can see.",
#    'popularity': 25.518,
#    'poster_path': '/5EufsDwXdY2CVttYOk2WtYhgKpa.jpg',
#    'release_date': '2020-02-26',
#    'title': 'The Invisible Man',
#    'video': False,
#    'vote_average': 7.118,
#    'vote_count': 5471}],
#  'total_pages': 291,
#  'total_results': 5805}

# %%
pd.DataFrame(data)
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/tintsaQ0WL...          291
# 1      1  {'adult': False, 'backdrop_path': '/stmYfCUGd8...          291
# 2      1  {'adult': False, 'backdrop_path': '/eAIHqfS3kX...          291
# 3      1  {'adult': False, 'backdrop_path': '/7dCzb1oa7A...          291
# 4      1  {'adult': False, 'backdrop_path': '/xFxk4vnirO...          291
# 5      1  {'adult': False, 'backdrop_path': '/uozb2VeD87...          291
# 6      1  {'adult': False, 'backdrop_path': '/ww7eC3BqSb...          291
# 7      1  {'adult': False, 'backdrop_path': '/2cbUXan4QU...          291
# 8      1  {'adult': False, 'backdrop_path': '/sizHX5Vbwl...          291
# 9      1  {'adult': False, 'backdrop_path': '/8HbqSozBJx...          291
# 10     1  {'adult': False, 'backdrop_path': '/tQprwIKzFx...          291
# 11     1  {'adult': False, 'backdrop_path': '/dzfiE2VHY3...          291
# 12     1  {'adult': False, 'backdrop_path': '/3pIqd1hgZ2...          291
# 13     1  {'adult': False, 'backdrop_path': '/23IeumCWwW...          291
# 14     1  {'adult': False, 'backdrop_path': '/42gqGeyXh4...          291
# 15     1  {'adult': False, 'backdrop_path': '/6mKAKhj8PO...          291
# 16     1  {'adult': False, 'backdrop_path': '/pQdZmXq0vv...          291
# 17     1  {'adult': False, 'backdrop_path': '/yFRpUmsreY...          291
# 18     1  {'adult': False, 'backdrop_path': '/tcrNJfyNEI...          291
# 19     1  {'adult': False, 'backdrop_path': '/tweDJNQzBG...          291
#
#     total_results
# 0            5805
# 1            5805
# 2            5805
# 3            5805
# 4            5805
# 5            5805
# 6            5805
# 7            5805
# 8            5805
# 9            5805
# 10           5805
# 11           5805
# 12           5805
# 13           5805
# 14           5805
# 15           5805
# 16           5805
# 17           5805
# 18           5805
# 19           5805

# %%
pd.DataFrame(data["results"])
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /tintsaQ0WLzZsTMkTiqtMB3rfc8.jpg             [28, 80, 35]  522627
# 1   False  /stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg     [28, 878, 35, 10751]  454626
# 2   False  /eAIHqfS3kXm7kZl4j7ZBfdegyEz.jpg             [53, 28, 80]   38700
# 3   False  /7dCzb1oa7ACYi66VIrE1wqmftAa.jpg                     [28]  660521
# 4   False  /xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg  [10751, 16, 12, 35, 14]  508439
# 5   False  /uozb2VeD87YmhoUP1RrGWfzuCrr.jpg                 [28, 80]  495764
# 6   False  /ww7eC3BqSbFsyE5H5qMde8WkxJ2.jpg        [27, 878, 28, 12]  443791
# 7   False  /2cbUXan4QUY1QoVnhhunJqpKR8y.jpg      [10751, 35, 14, 12]  448119
# 8   False  /sizHX5VbwlBihaathTQHVGk1jdi.jpg            [878, 18, 28]  514207
# 9   False  /8HbqSozBJxv6UldR9lMUECUlbLI.jpg            [878, 12, 28]  430155
# 10  False   /tQprwIKzFx83JpM5dVrGRC4UpF.jpg       [16, 12, 14, 9648]  573730
# 11  False  /dzfiE2VHY362dGI62XfZ2iI87CT.jpg       [27, 14, 12, 9648]  539537
# 12  False  /3pIqd1hgZ2xqzWEyiYp4blqE9Fi.jpg             [53, 36, 18]  522241
# 13  False  /23IeumCWwWE7u2d2FDNSGPsNRbl.jpg             [18, 27, 53]  474764
# 14  False  /42gqGeyXh4caHP19Tqf8DMRgc7r.jpg              [35, 10749]  556678
# 15  False  /6mKAKhj8POVGqV1GsroS5mGIUe9.jpg             [14, 28, 12]  666750
# 16  False  /pQdZmXq0vvKP1RYUrDHQkzMlS4x.jpg         [16, 28, 12, 14]  571265
# 17  False  /yFRpUmsreYO5Bc0HVBTsJsHIIox.jpg          [12, 10751, 18]  481848
# 18  False  /tcrNJfyNEIqaBR8Ogkgnq5xQJnf.jpg              [10749, 18]  342470
# 19  False  /tweDJNQzBGgsWVF5MC8JhSAk07p.jpg            [53, 878, 27]  570670
#
#    original_language                                     original_title  \
# 0                 en                                      The Gentlemen
# 1                 en                                 Sonic the Hedgehog
# 2                 en                                  Bad Boys for Life
# 3                 en                                      The Mercenary
# 4                 en                                             Onward
# 5                 en  Birds of Prey (and the Fantabulous Emancipatio...
# 6                 en                                         Underwater
# 7                 en                                           Dolittle
# 8                 ru                                          Вторжение
# 9                 ru                                               Кома
# 10                ja                                 劇場版メイドインアビス 深き魂の黎明
# 11                en                                     Fantasy Island
# 12                en                                        The Courier
# 13                en                                          The Lodge
# 14                en                                              Emma.
# 15                en                             Dragonheart: Vengeance
# 16                ja                       デジモンアドベンチャー LAST EVOLUTION 絆
# 17                en                               The Call of the Wild
# 18                en                              All the Bright Places
# 19                en                                  The Invisible Man
#
#                                              overview  popularity  \
# 0   American expat Mickey Pearson has built a high...      97.875
# 1   Powered with incredible speed, Sonic The Hedge...      67.362
# 2   Marcus and Mike are forced to confront new thr...      54.064
# 3   When a mission in South America goes wrong a m...      47.497
# 4   In a suburban fantasy world, two teenage elf b...      43.404
# 5   Harley Quinn joins forces with a singer, an as...      40.330
# 6   After an earthquake destroys their underwater ...      37.901
# 7   After losing his wife seven years earlier, the...      36.406
# 8   Two years after the fall of the alien ship, th...      35.654
# 9   A young and talented architect comes to his se...      33.987
# 10  A continuation of the epic adventure of plucky...      29.612
# 11  A group of contest winners arrive at an island...      29.065
# 12  Cold War spy Greville Wynne and his Russian so...      28.853
# 13  When a father is forced to abruptly depart for...      27.495
# 14  In 1800s England, a well-meaning but selfish y...      26.989
# 15  Lukas, a young farmer whose family is killed b...      26.776
# 16  Tai is now a university student, living alone,...      26.753
# 17  Buck is a big-hearted dog whose blissful domes...      26.029
# 18  Two teens facing personal struggles form a pow...      25.525
# 19  When Cecilia's abusive ex takes his own life a...      25.518
#
#                          poster_path release_date  \
# 0   /jtrhTYB7xSrJxR1vusu99nvnZ1g.jpg   2020-01-01
# 1   /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg   2020-02-12
# 2   /y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg   2020-01-15
# 3   /p3wgefagejlefFEDsLRHiXU7NGu.jpg   2020-01-07
# 4   /f4aul3FyD3jv3v4bul1IrkWZvzq.jpg   2020-02-29
# 5   /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg   2020-02-05
# 6   /gzlbb3yeVISpQ3REd3Ga1scWGTU.jpg   2020-01-08
# 7   /uoplwswBDy7gsOyrbGuKyPFoPCs.jpg   2020-01-02
# 8   /dqKqzcdhtJwOhjqe89RTURqILtl.jpg   2020-01-01
# 9   /ijJm0RSeKIr67qkHLtSmtigS6ra.jpg   2020-01-01
# 10  /fsPZdpocYYbvDS2YEE1Xohqo1ni.jpg   2020-01-17
# 11  /8ZMrZGGW65ePWIgRn1260nA1uUm.jpg   2020-02-12
# 12  /zFIjKtZrzhmc7HecdFXXjsLR2Ig.jpg   2020-01-24
# 13  /yake2myhbW7c6dKbmwYDy1i40bm.jpg   2020-01-16
# 14  /uHpHzbHLSsVmAuuGuQSpyVDZmDc.jpg   2020-02-13
# 15  /qs6gz6atyQcAvqC6qZaslOjliUG.jpg   2020-02-04
# 16  /z3l5iwWQLxcInVnNkC8k8hxqZ60.jpg   2020-02-21
# 17  /33VdppGbeNxICrFUtW2WpGHvfYc.jpg   2020-02-19
# 18  /4SafxuMKQiw4reBiWKVZJpJn80I.jpg   2020-02-28
# 19  /5EufsDwXdY2CVttYOk2WtYhgKpa.jpg   2020-02-26
#
#                                                 title  video  vote_average  \
# 0                                       The Gentlemen  False         7.681
# 1                                  Sonic the Hedgehog  False         7.333
# 2                                   Bad Boys for Life  False         7.130
# 3                                       The Mercenary  False         6.104
# 4                                              Onward  False         7.703
# 5   Birds of Prey (and the Fantabulous Emancipatio...  False         6.900
# 6                                          Underwater  False         6.287
# 7                                            Dolittle  False         6.623
# 8                                            Invasion  False         6.929
# 9                                                Coma  False         6.392
# 10               Made in Abyss: Dawn of the Deep Soul  False         7.899
# 11                                     Fantasy Island  False         5.815
# 12                                        The Courier  False         7.039
# 13                                          The Lodge  False         6.121
# 14                                              Emma.  False         7.041
# 15                             Dragonheart: Vengeance  False         6.877
# 16           Digimon Adventure: Last Evolution Kizuna  False         8.100
# 17                               The Call of the Wild  False         7.567
# 18                              All the Bright Places  False         7.655
# 19                                  The Invisible Man  False         7.118
#
#     vote_count
# 0         5392
# 1         9175
# 2         7720
# 3           24
# 4         5893
# 5         9903
# 6         2943
# 7         3497
# 8          760
# 9          499
# 10         203
# 11        2331
# 12        1036
# 13        1170
# 14        1628
# 15         300
# 16         231
# 17        3543
# 18        2767
# 19        5471

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %%
import pandas as pd
import requests
import json
pd.options.display.max_columns = 30

# %%
movie_id = [0, 299534, 19995, 140607, 299536, 597, 135397,
            420818, 24428, 168259, 99861, 284054, 12445,
            181808, 330457, 351286, 109445, 321612, 260513]

# %%
basic_url = 'https://api.themoviedb.org/3/movie/{}?{}'

# %%
json_list = []
for movie in movie_id:
    url = basic_url.format(movie, api_key)
    r = requests.get(url)
    if r.status_code != 200:
        continue
    else:
        data = r.json()
        json_list.append(data) 
df = pd.DataFrame(json_list)

# %%
requests.get(basic_url.format(0, api_key)).status_code
# Out:
# 404

# %%
df
# Out:
#     adult                     backdrop_path  \
# 0   False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1   False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 2   False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# 3   False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4   False  /sCzcYW9h55WcesOqA12cgEr9Exw.jpg
# 5   False  /dF6FjTZzRTENfB4R17HDN20jLT2.jpg
# 6   False  /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg
# 7   False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 8   False  /cHkhb5A4gQRK6zs6Pv7zorHs8Nk.jpg
# 9   False  /6YwkGolwdOMNpbTOmLjoehlVWs5.jpg
# 10  False  /b6ZJZHUdMEFECvGiDpJjlfUWela.jpg
# 11  False  /n5A7brJCjejceZmHyujwUTVgQNC.jpg
# 12  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg
# 13  False  /xJWPZIYOEFIjZpBL7SVBGnzRYXp.jpg
# 14  False  /3s9O5af2xWKWR5JzP2iJZpZeQQg.jpg
# 15  False  /fydUcbkqLyESCFa9U5XKqi8dIVj.jpg
# 16  False  /m3tdSyl11fhgXPDSEt3aBctTqGP.jpg
# 17  False  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg
#
#                                 belongs_to_collection     budget  \
# 0   {'id': 86311, 'name': 'The Avengers Collection...  356000000
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
# 3   {'id': 86311, 'name': 'The Avengers Collection...  300000000
# 4                                                None  200000000
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...  150000000
# 6   {'id': 762512, 'name': 'The Lion King (Reboot)...  260000000
# 7   {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 8   {'id': 9485, 'name': 'The Fast and the Furious...  190000000
# 9   {'id': 86311, 'name': 'The Avengers Collection...  365000000
# 10  {'id': 529892, 'name': 'Black Panther Collecti...  200000000
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...  200000000
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...  170000000
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000
# 16                                               None  160000000
# 17  {'id': 468222, 'name': 'The Incredibles Collec...  200000000
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 13  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                              homepage      id    imdb_id  \
# 0      https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# 1                https://www.avatar.com/movies/avatar   19995  tt0499549
# 2   http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3   https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4      https://www.paramountmovies.com/movies/titanic     597  tt0120338
# 5                       http://www.jurassicworld.com/  135397  tt0369610
# 6        https://movies.disney.com/the-lion-king-2019  420818  tt6105098
# 7          https://www.marvel.com/movies/the-avengers   24428  tt0848228
# 8           https://www.thefastsaga.com/fast-saga/ff7  168259  tt2820852
# 9   http://marvel.com/movies/movie/193/avengers_ag...   99861  tt2395427
# 10        https://www.marvel.com/movies/black-panther  284054  tt1825683
# 11  https://www.warnerbros.com/movies/harry-potter...   12445  tt1201607
# 12  https://www.starwars.com/films/star-wars-episo...  181808  tt2527336
# 13                 https://movies.disney.com/frozen-2  330457  tt4520988
# 14  https://www.uphe.com/movies/jurassic-world-fal...  351286  tt4881806
# 15                    http://movies.disney.com/frozen  109445  tt2294629
# 16  http://movies.disney.com/beauty-and-the-beast-...  321612  tt2771200
# 17            https://movies.disney.com/incredibles-2  260513  tt3606756
#
#    original_language                                original_title  \
# 0                 en                             Avengers: Endgame
# 1                 en                                        Avatar
# 2                 en                  Star Wars: The Force Awakens
# 3                 en                        Avengers: Infinity War
# 4                 en                                       Titanic
# 5                 en                                Jurassic World
# 6                 en                                 The Lion King
# 7                 en                                  The Avengers
# 8                 en                                     Furious 7
# 9                 en                       Avengers: Age of Ultron
# 10                en                                 Black Panther
# 11                en  Harry Potter and the Deathly Hallows: Part 2
# 12                en                      Star Wars: The Last Jedi
# 13                en                                     Frozen II
# 14                en                Jurassic World: Fallen Kingdom
# 15                en                                        Frozen
# 16                en                          Beauty and the Beast
# 17                en                                 Incredibles 2
#
#                                              overview  popularity  \
# 0   After the devastating events of Avengers: Infi...      97.509
# 1   In the 22nd century, a paraplegic Marine is di...     113.289
# 2   Thirty years after defeating the Galactic Empi...      57.727
# 3   As the Avengers and their allies have continue...     156.312
# 4   101-year-old Rose DeWitt Bukater tells the sto...     111.747
# 5   Twenty-two years after the events of Jurassic ...      69.451
# 6   Simba idolizes his father, King Mufasa, and ta...      79.987
# 7   When an unexpected enemy emerges and threatens...     105.944
# 8   Deckard Shaw seeks revenge against Dominic Tor...      69.961
# 9   When Tony Stark tries to jumpstart a dormant p...      81.763
# 10  King T'Challa returns home to the reclusive, t...      91.651
# 11  Harry, Ron and Hermione continue their quest t...      90.430
# 12  Rey develops her newly discovered abilities wi...      61.603
# 13  Elsa, Anna, Kristoff and Olaf head far into th...      73.628
# 14  Three years after Jurassic World was destroyed...      60.362
# 15  Young princess Anna of Arendelle dreams about ...      95.124
# 16  A live-action adaptation of Disney's version o...      73.292
# 17  Elastigirl springs into action to save the day...      71.130
#
#                          poster_path  \
# 0   /or06FN3Dka5tukK1e9sl16pB3iy.jpg
# 1   /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 2   /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 3   /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
# 4   /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
# 5   /A0LZHXUzo5C60Oahvt7VxvwuzHw.jpg
# 6   /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg
# 7    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# 8   /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg
# 9   /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg
# 10  /uxzzxijgPIY7slzFvMotPv8wjKA.jpg
# 11  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg
# 12  /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg
# 13  /mINJaa34MtknCYl5AjtNJzWj8cD.jpg
# 14  /c9XxwwhPHdaImA2f1WEfEsbhaFB.jpg
# 15  /kgwjIb2JDHRhNk13lmSxiClFjVk.jpg
# 16  /hKegSKIDep2ewJWPUQD7u0KqFIp.jpg
# 17  /9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg
#
#                                  production_companies  \
# 0   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 1   [{'id': 444, 'logo_path': None, 'name': 'Dune ...
# 2   [{'id': 1, 'logo_path': '/tlVSws0RvvtPBwViUyOF...
# 3   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4   [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# 5   [{'id': 56, 'logo_path': '/cEaxANEisCqeEoRvODv...
# 6   [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 7   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 8   [{'id': 333, 'logo_path': '/5xUJfzPZ8jWJUDzYtI...
# 9   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 10  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 11  [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4...
# 12  [{'id': 1, 'logo_path': '/tlVSws0RvvtPBwViUyOF...
# 13  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 14  [{'id': 56, 'logo_path': '/cEaxANEisCqeEoRvODv...
# 15  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 16  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 17  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
#
#                                  production_countries release_date  \
# 0   [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24
# 1   [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-15
# 2   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15
# 3   [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25
# 4   [{'iso_3166_1': 'US', 'name': 'United States o...   1997-11-18
# 5   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-06-06
# 6   [{'iso_3166_1': 'US', 'name': 'United States o...   2019-07-12
# 7   [{'iso_3166_1': 'US', 'name': 'United States o...   2012-04-25
# 8   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-01
# 9   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-22
# 10  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-02-13
# 11  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2011-07-12
# 12  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-12-13
# 13  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-11-20
# 14  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-06-06
# 15  [{'iso_3166_1': 'US', 'name': 'United States o...   2013-11-20
# 16  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-03-16
# 17  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-06-14
#
#        revenue  runtime                                   spoken_languages  \
# 0   2800000000      181  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1   2923706026      162  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2   2068223624      136  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3   2052415039      149  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4   2264162353      194  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5   1671537444      124  [{'english_name': 'English', 'iso_639_1': 'en'...
# 6   1663000000      118  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7   1518815515      143  [{'english_name': 'English', 'iso_639_1': 'en'...
# 8   1515400000      137  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...
# 9   1405403694      141  [{'english_name': 'English', 'iso_639_1': 'en'...
# 10  1349926083      135  [{'english_name': 'English', 'iso_639_1': 'en'...
# 11  1341511219      130  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12  1332698830      152  [{'english_name': 'English', 'iso_639_1': 'en'...
# 13  1450000000      103  [{'english_name': 'English', 'iso_639_1': 'en'...
# 14  1310466296      129  [{'english_name': 'English', 'iso_639_1': 'en'...
# 15  1274219009      102  [{'english_name': 'English', 'iso_639_1': 'en'...
# 16  1266115964      129  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 17  1242805359      118  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#       status                                            tagline  \
# 0   Released                                 Avenge the fallen.
# 1   Released                        Enter the world of Pandora.
# 2   Released                      Every generation has a story.
# 3   Released              An entire universe. Once and for all.
# 4   Released          Nothing on Earth could come between them.
# 5   Released                                  The park is open.
# 6   Released                             The King has Returned.
# 7   Released                            Some assembly required.
# 8   Released                               Vengeance hits home.
# 9   Released                                A new age has come.
# 10  Released                                Long live the king.
# 11  Released                                       It all ends.
# 12  Released
# 13  Released                     The past is not what it seems.
# 14  Released                                  The park is gone.
# 15  Released  Only the act of true love will thaw a frozen h...
# 16  Released                                      Be our guest.
# 17  Released         It's time to get back to being incredible.
#
#                                            title  video  vote_average  \
# 0                              Avengers: Endgame  False         8.257
# 1                                         Avatar  False         7.580
# 2                   Star Wars: The Force Awakens  False         7.285
# 3                         Avengers: Infinity War  False         8.248
# 4                                        Titanic  False         7.904
# 5                                 Jurassic World  False         6.686
# 6                                  The Lion King  False         7.116
# 7                                   The Avengers  False         7.700
# 8                                      Furious 7  False         7.235
# 9                        Avengers: Age of Ultron  False         7.273
# 10                                 Black Panther  False         7.400
# 11  Harry Potter and the Deathly Hallows: Part 2  False         8.098
# 12                      Star Wars: The Last Jedi  False         6.809
# 13                                     Frozen II  False         7.260
# 14                Jurassic World: Fallen Kingdom  False         6.547
# 15                                        Frozen  False         7.247
# 16                          Beauty and the Beast  False         7.000
# 17                                 Incredibles 2  False         7.500
#
#     vote_count
# 0        24629
# 1        30631
# 2        18782
# 3        28640
# 4        24419
# 5        19810
# 6         9580
# 7        29832
# 8        10251
# 9        22280
# 10       21508
# 11       19806
# 12       14733
# 13        9358
# 14       11347
# 15       15954
# 16       15105
# 17       12376

# %%
df = df.loc[:, ["title", "id", "revenue", "genres", "belongs_to_collection", "runtime"]].sort_values(by = "revenue",
                                                                                                ascending = False)

# %%
df
# Out:
#                                            title      id     revenue  \
# 1                                         Avatar   19995  2923706026
# 0                              Avengers: Endgame  299534  2800000000
# 4                                        Titanic     597  2264162353
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2052415039
# 5                                 Jurassic World  135397  1671537444
# 6                                  The Lion King  420818  1663000000
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515400000
# 13                                     Frozen II  330457  1450000000
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1349926083
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1266115964
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  \
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 13  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 4                                                None      194
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6   {'id': 762512, 'name': 'The Lion King (Reboot)...      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      103
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      135
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.to_json("movies.json", orient = "records")

# %%
with open("movies.json") as f:
    data = json.load(f)

# %%
pd.json_normalize(data)
# Out:
#                                            title      id     revenue  \
# 0                                         Avatar   19995  2923706026
# 1                              Avengers: Endgame  299534  2800000000
# 2                                        Titanic     597  2264162353
# 3                   Star Wars: The Force Awakens  140607  2068223624
# 4                         Avengers: Infinity War  299536  2052415039
# 5                                 Jurassic World  135397  1671537444
# 6                                  The Lion King  420818  1663000000
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515400000
# 9                                      Frozen II  330457  1450000000
# 10                       Avengers: Age of Ultron   99861  1405403694
# 11                                 Black Panther  284054  1349926083
# 12  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 13                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1266115964
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  runtime  \
# 0   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      162
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      181
# 2   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      194
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      136
# 4   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      149
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      124
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...      118
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...      143
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      137
# 9   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...      103
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      141
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      135
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      130
# 13  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      152
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      129
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...      102
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...      129
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      118
#
#     belongs_to_collection.id           belongs_to_collection.name  \
# 0                    87096.0                    Avatar Collection
# 1                    86311.0              The Avengers Collection
# 2                        NaN                                  NaN
# 3                       10.0                 Star Wars Collection
# 4                    86311.0              The Avengers Collection
# 5                      328.0             Jurassic Park Collection
# 6                   762512.0    The Lion King (Reboot) Collection
# 7                    86311.0              The Avengers Collection
# 8                     9485.0  The Fast and the Furious Collection
# 9                   386382.0                    Frozen Collection
# 10                   86311.0              The Avengers Collection
# 11                  529892.0             Black Panther Collection
# 12                    1241.0              Harry Potter Collection
# 13                      10.0                 Star Wars Collection
# 14                     328.0             Jurassic Park Collection
# 15                  386382.0                    Frozen Collection
# 16                       NaN                                  NaN
# 17                  468222.0           The Incredibles Collection
#
#    belongs_to_collection.poster_path belongs_to_collection.backdrop_path  \
# 0   /uO2yU3QiGHvVp0L5e5IatTVRkYk.jpg    /gxnvX9kF7RRUQYvB52dMLPgeJkt.jpg
# 1   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 2                                NaN                                 NaN
# 3   /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 4   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 5   /jcUXVtJ6s0NG0EaxllQCAUtqdr0.jpg    /njFixYzIxX8jsn6KMSEtAzi4avi.jpg
# 6   /dGpIRn4Nqi63JO1RlKxjcPbQSAw.jpg    /jIgM7YNVft0YGeXsqrh3oG5TWLx.jpg
# 7   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 8   /rKKSOVv6iU3nULrKQmd9uEx9gez.jpg    /56h4DCt0ogIRI7B71xD5iA5hES1.jpg
# 9   /dwdyvzFX9NEI7oFlRnZurRmlswQ.jpg    /s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg
# 10  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 11  /qT1JPO6IltC2B39QAriAg7SelMx.jpg    /nsiBzWsmmerBMuD8TKHpYBTnfhD.jpg
# 12  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /hWK8gTH2riuv65Ej43hPSeE16Mu.jpg
# 13  /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 14  /jcUXVtJ6s0NG0EaxllQCAUtqdr0.jpg    /njFixYzIxX8jsn6KMSEtAzi4avi.jpg
# 15  /dwdyvzFX9NEI7oFlRnZurRmlswQ.jpg    /s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg
# 16                               NaN                                 NaN
# 17  /xMX1jZyObVeWUxDQmt53X6jzIO4.jpg    /6oi6V1O9MJRNnfV8E9JMntmFqBD.jpg
#
#     belongs_to_collection
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN

# %%
pd.json_normalize(data, "genres", "title")
# Out:
#        id             name                                         title
# 0      28           Action                                        Avatar
# 1      12        Adventure                                        Avatar
# 2      14          Fantasy                                        Avatar
# 3     878  Science Fiction                                        Avatar
# 4      12        Adventure                             Avengers: Endgame
# 5     878  Science Fiction                             Avengers: Endgame
# 6      28           Action                             Avengers: Endgame
# 7      18            Drama                                       Titanic
# 8   10749          Romance                                       Titanic
# 9      12        Adventure                  Star Wars: The Force Awakens
# 10     28           Action                  Star Wars: The Force Awakens
# 11    878  Science Fiction                  Star Wars: The Force Awakens
# 12     12        Adventure                        Avengers: Infinity War
# 13     28           Action                        Avengers: Infinity War
# 14    878  Science Fiction                        Avengers: Infinity War
# 15     28           Action                                Jurassic World
# 16     12        Adventure                                Jurassic World
# 17    878  Science Fiction                                Jurassic World
# 18     53         Thriller                                Jurassic World
# 19     12        Adventure                                 The Lion King
# 20     18            Drama                                 The Lion King
# 21  10751           Family                                 The Lion King
# 22     16        Animation                                 The Lion King
# 23    878  Science Fiction                                  The Avengers
# 24     28           Action                                  The Avengers
# 25     12        Adventure                                  The Avengers
# 26     28           Action                                     Furious 7
# 27     53         Thriller                                     Furious 7
# 28     80            Crime                                     Furious 7
# 29  10751           Family                                     Frozen II
# 30     16        Animation                                     Frozen II
# 31     12        Adventure                                     Frozen II
# 32     35           Comedy                                     Frozen II
# 33     14          Fantasy                                     Frozen II
# 34     28           Action                       Avengers: Age of Ultron
# 35     12        Adventure                       Avengers: Age of Ultron
# 36    878  Science Fiction                       Avengers: Age of Ultron
# 37     28           Action                                 Black Panther
# 38     12        Adventure                                 Black Panther
# 39    878  Science Fiction                                 Black Panther
# 40     14          Fantasy  Harry Potter and the Deathly Hallows: Part 2
# 41     12        Adventure  Harry Potter and the Deathly Hallows: Part 2
# 42     12        Adventure                      Star Wars: The Last Jedi
# 43     28           Action                      Star Wars: The Last Jedi
# 44    878  Science Fiction                      Star Wars: The Last Jedi
# 45     28           Action                Jurassic World: Fallen Kingdom
# 46     12        Adventure                Jurassic World: Fallen Kingdom
# 47    878  Science Fiction                Jurassic World: Fallen Kingdom
# 48     53         Thriller                Jurassic World: Fallen Kingdom
# 49     16        Animation                                        Frozen
# 50  10751           Family                                        Frozen
# 51     12        Adventure                                        Frozen
# 52     14          Fantasy                                        Frozen
# 53  10751           Family                          Beauty and the Beast
# 54     14          Fantasy                          Beauty and the Beast
# 55  10749          Romance                          Beauty and the Beast
# 56     28           Action                                 Incredibles 2
# 57     12        Adventure                                 Incredibles 2
# 58     16        Animation                                 Incredibles 2
# 59  10751           Family                                 Incredibles 2

# %% [markdown]
# # Importing and Saving the Movies Dataset (Real World Scenario)

# %%
df
# Out:
#                                            title      id     revenue  \
# 1                                         Avatar   19995  2923706026
# 0                              Avengers: Endgame  299534  2800000000
# 4                                        Titanic     597  2264162353
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2052415039
# 5                                 Jurassic World  135397  1671537444
# 6                                  The Lion King  420818  1663000000
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515400000
# 13                                     Frozen II  330457  1450000000
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1349926083
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1266115964
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  \
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 13  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 4                                                None      194
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6   {'id': 762512, 'name': 'The Lion King (Reboot)...      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      103
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      135
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.to_csv("movies_raw.csv", index = False)

# %%
df = pd.read_csv("movies_raw.csv")

# %%
df
# Out:
#                                            title      id     revenue  \
# 0                                         Avatar   19995  2923706026
# 1                              Avengers: Endgame  299534  2800000000
# 2                                        Titanic     597  2264162353
# 3                   Star Wars: The Force Awakens  140607  2068223624
# 4                         Avengers: Infinity War  299536  2052415039
# 5                                 Jurassic World  135397  1671537444
# 6                                  The Lion King  420818  1663000000
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515400000
# 9                                      Frozen II  330457  1450000000
# 10                       Avengers: Age of Ultron   99861  1405403694
# 11                                 Black Panther  284054  1349926083
# 12  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 13                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1266115964
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  \
# 0   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 2   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 1   {'id': 86311, 'name': 'The Avengers Collection...      181
# 2                                                 NaN      194
# 3   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 4   {'id': 86311, 'name': 'The Avengers Collection...      149
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6   {'id': 762512, 'name': 'The Lion King (Reboot)...      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 386382, 'name': 'Frozen Collection', 'p...      103
# 10  {'id': 86311, 'name': 'The Avengers Collection...      141
# 11  {'id': 529892, 'name': 'Black Panther Collecti...      135
# 12  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 13  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                                NaN      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.genres[0]
# Out:
# "[{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 878, 'name': 'Science Fiction'}]"
